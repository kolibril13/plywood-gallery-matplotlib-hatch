# %%
from plywood_gallery import ChapterConfig

#
ChapterConfig.clean_all(skip_warning=True)
ChapterConfig.generate_json()
ChapterConfig.reset_counter()

import matplotlib.pyplot as plt



cell_header = '-p Header1.png --celltype Header --style "height: auto; width: 60px;"'
cell_normal = '-p Normal.png  --celltype Normal --style "height: 140px; width: auto;"'
# Out:
# This path and all its child elements will be removed:/Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-matplotlib-hatch/gallery_assets
# Deleted '/Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-matplotlib-hatch/gallery_assets' and all containing files and folder.
# Successfully created /Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-matplotlib-hatch/gallery_assets/gallery_parameters.json!🦫

# %%
ChapterConfig.set_chapter_name("Import")

# %%
# %%capture_png $cell_header
#
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
#
# %config InlineBackend.figure_format='retina' # NOT
# plt.rcParams['figure.dpi'] = 150  # NOT
# plt.rcParams['lines.linewidth'] = 2 # NOT
# fix, ax = plt.subplots(figsize=(5, 5), facecolor="#F7F5F3")  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)  # NOT
# ax.axis("off");  # NOT
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
ChapterConfig.set_chapter_name("Single")

# %%
fig, axs = plt.subplots(2, 5, constrained_layout=True, figsize=(6.4, 3.2))

hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']


def hatches_plot(ax, h):
    ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
    ax.text(1, -0.5, f"' {h} '", size=15, ha="center")
    ax.axis('equal')
    ax.axis('off')

for ax, h in zip(axs.flat, hatches):
    hatches_plot(ax, h)

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '/'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' / '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '\\'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' \\ '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  '|'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' | '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '-'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' - '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '+'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' + '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'x'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' x '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'o'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' o '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'O'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' O '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '.'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' . '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '*'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#F7F5F3")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' * '")

# %%
ChapterConfig.set_chapter_name("Double")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '//'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' // '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '\\\\'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' \\\\ '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  '||'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' || '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '--'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' -- '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '++'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' ++ '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'xx'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' xx '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'oo'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' oo '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'OO'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' OO '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '..'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' .. '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '**'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#d3ffce")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' ** '")

# %%
ChapterConfig.set_chapter_name("Mixed")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '/o'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' /o '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '\\|'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' \\| '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  '|*'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' |* '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '-\\'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' -\\ '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = '+o'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' +o '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h = 'x*'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' x* '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  'o-'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' o- '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  'O|'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' O| '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  'O.'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' O. '")

# %%
# %%capture_png -p entry.png --celltype Normal --style "width:55px"
# h =  '*-'
# fig, ax = plt.subplots(figsize=(1, 1),facecolor="#FFFF66")
# ax.add_patch(Rectangle((0, 0), 2, 2, fill=False, hatch=h))
# ax.axis('off')
# ax.axis('equal')
# plt.title(f"' {h} '");
# Out:
# Text(0.5, 1.0, "' *- '")
